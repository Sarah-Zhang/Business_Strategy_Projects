# %% [markdown]
# group 1: 15% margin
# group 2: 18% margin
#
# $H_0: \pi_1 = \pi_2 \\ H_A: \pi_1 < \pi_2$

# %%
p1 = 22/122
p2 = 24/132
n1 = 122
n2 = 132
z = (p1-p2) / sqrt( p1*(1-p1)/n1 + p2*(1-p2)/n2 )

# %%
pnorm(q = z, lower.tail = T)
# Out:
# [1] 0.4877073

# %%
install.packages('pwr')
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(pwr)
library(ggplot2)

# %%
h = seq(from = 0.1, to = 0.5, by = 0.02)
out = pwr.2p2n.test(h = h, n1 = n1, n2 = n2, sig.level = 0.05, alternative = 'greater')
out
# Out:
#      difference of proportion power calculation for binomial distribution (arcsine transformation)
#
#               h = 0.10, 0.12, 0.14, 0.16, 0.18, 0.20, 0.22, 0.24, 0.26, 0.28, 0.30, 0.32, 0.34, 0.36, 0.38, 0.40, 0.42, 0.44, 0.46, 0.48, 0.50
#              n1 = 122
#              n2 = 132
#       sig.level = 0.05
#           power = 0.1980512, 0.2453008, 0.2980206, 0.3553739, 0.4162089, 0.4791243, 0.5425653, 0.6049377, 0.6647271, 0.7206082, 0.7715314, 0.8167768, 0.8559729, 0.8890800, 0.9163452, 0.9382382, 0.9553782, 0.9684617, 0.9781992, 0.9852654, 0.9902648
#     alternative = greater
#
# NOTE: different sample sizes

# %%
pplot = as.data.frame(cbind(out$h, out$power))
colnames(pplot) = c("effect_size","power")
options(repr.plot.width=4, repr.plot.height=3)
print(ggplot(pplot, aes(x = effect_size, y = power)) + geom_path() + theme_classic())
# Out:
# plot without title
